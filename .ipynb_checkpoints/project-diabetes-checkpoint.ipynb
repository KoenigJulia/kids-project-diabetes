# %% [markdown]
# # Diabetes

# %% [markdown]
# ## Data Preprocessing

# %%
import pandas as pd

# %%
diabetes = pd.read_csv('diabetes.csv')
diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
diabetes.info()
diabetes.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# ...

# %% [markdown]
# ## Was fällt auf?
# Die statistischen Daten haben immer ein Minimum von 0. Aber es ist nicht möglich, dass ein Mensch keine Haut hat oder BMI von 0 hat.

# %% [markdown]
# ## Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
diabetes_data = pd.read_csv('diabetes.csv')
diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
diabetes_colors = sns.xkcd_palette(['apple green', 'cranberry'])
sns.palplot(diabetes_colors)

# %% [markdown]
# # Was hat das Ergebnis mit Glucose zu tun?
# In diesen Boxplots ist abgebildet, ob das Risiko für Diabetes steigt je öfter man schwanger war. Die Antwort ist JA.

# %%
 sns.boxplot(data=diabetes_data, x='Outcome', y='Glucose', palette=diabetes_colors, whis=[1,99])
# Out:
# <AxesSubplot: xlabel='Outcome', ylabel='Glucose'>

# %%
sns.boxplot(data=diabetes_data, x='Outcome', y='Glucose', color='lightgray', whis=[1,99])
sns.swarmplot(data=diabetes_data, x='Outcome', y='Glucose', palette=diabetes_colors, hue='Outcome')
# Out:
# /Users/tamaramelcher/opt/miniconda3/envs/leoenv/lib/python3.10/site-packages/seaborn/categorical.py:3543: UserWarning: 10.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot: xlabel='Outcome', ylabel='Glucose'>
# /Users/tamaramelcher/opt/miniconda3/envs/leoenv/lib/python3.10/site-packages/seaborn/categorical.py:3543: UserWarning: 10.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/tamaramelcher/opt/miniconda3/envs/leoenv/lib/python3.10/site-packages/seaborn/categorical.py:3543: UserWarning: 10.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.violinplot(data=diabetes_data, x='Outcome', y='Glucose', palette=diabetes_colors, hue='Outcome')
# Out:
# <AxesSubplot: xlabel='Outcome', ylabel='Glucose'>

# %% [markdown]
# # Was hat Insulin mit dem Ergebnis zu tun?

# %%
sns.violinplot(data=diabetes_data, x='Outcome', y='Insulin', palette=diabetes_colors, hue='Outcome')
# Out:
# <AxesSubplot: xlabel='Outcome', ylabel='Insulin'>

# %%
sns.histplot(data=diabetes_data, x='Insulin', palette=diabetes_colors, hue='Outcome', bins=10)
# Out:
# <AxesSubplot: xlabel='Insulin', ylabel='Count'>

# %%
sns.histplot(data=diabetes_data, x='Insulin', palette=diabetes_colors, hue='Outcome', element='poly')
# Out:
# <AxesSubplot: xlabel='Insulin', ylabel='Count'>

# %%
sns.violinplot(data=diabetes_data, x='Outcome', y='Insulin', color='lightgray', hue='Outcome',split='true', inner='quarter')
sns.stripplot(data=diabetes_data, x='Outcome', y='Insulin', palette='cool', hue='Outcome', dodge='true')
# Out:
# <AxesSubplot: xlabel='Outcome', ylabel='Insulin'>

# %% [markdown]
# ## Was wirkt sich auf Glucose aus?

# %%
sns.histplot(data=diabetes_data, x='Glucose', y='BMI', palette=diabetes_colors, hue='Outcome', bins=10)
# Out:
# <AxesSubplot: xlabel='Glucose', ylabel='BMI'>

# %% [markdown]
# In diesem Histplot ist klar zu erkennen, das je größer der BMI ist, desto höher die Glucose.

# %%
sns.histplot(data=diabetes_data, x='Glucose', y='BMI', palette=diabetes_colors, hue='Outcome', element='poly')
# Out:
# <AxesSubplot: xlabel='Glucose', ylabel='BMI'>

# %%
sns.scatterplot(data=diabetes_data, x="Glucose", y="Pregnancies",hue='Outcome', palette=diabetes_colors)
# Out:
# <AxesSubplot: xlabel='Glucose', ylabel='Pregnancies'>

# %%
sns.scatterplot(data=diabetes_data, x="Glucose", y="BloodPressure",hue='Outcome', palette=diabetes_colors)
# Out:
# <AxesSubplot: xlabel='Glucose', ylabel='BloodPressure'>

# %% [markdown]
# ## Was wirkt sich auf die Menge an Insulin im Blut aus?

# %%
sns.histplot(data=diabetes_data, x='Insulin', palette=diabetes_colors, hue='Outcome', bins=10)
# Out:
# <AxesSubplot: xlabel='Insulin', ylabel='Count'>

# %%
sns.histplot(data=diabetes_data, x='Insulin', palette=diabetes_colors, hue='Outcome', element='poly')
# Out:
# <AxesSubplot: xlabel='Insulin', ylabel='Count'>
