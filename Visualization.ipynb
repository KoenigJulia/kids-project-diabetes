# %% [markdown]
# # Diabetes => Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
diabetes_data = pd.read_csv('diabetes.csv')
diabetes_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
diabetes_colors = sns.xkcd_palette(['apple green', 'cranberry'])
sns.palplot(diabetes_colors)

# %% [markdown]
# # Was hat Insulin mit Diabetes zu tun?

# %%
sns.histplot(data=diabetes_data, x='Insulin', palette=diabetes_colors, hue='Outcome', bins=10)
# Out:
# <AxesSubplot: xlabel='Insulin', ylabel='Count'>

# %%
sns.histplot(data=diabetes_data, x='Insulin', palette=diabetes_colors, hue='Outcome', element='poly')
# Out:
# <AxesSubplot: xlabel='Insulin', ylabel='Count'>

# %%
sns.boxplot(data=diabetes_data, x='Outcome', y='Insulin', color='lightgray', whis=[1,99])
sns.swarmplot(data=diabetes_data, x='Outcome', y='Insulin', palette=diabetes_colors, hue='Outcome')
# Out:
# /Users/tamaramelcher/opt/miniconda3/envs/leoenv/lib/python3.10/site-packages/seaborn/categorical.py:3543: UserWarning: 47.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/tamaramelcher/opt/miniconda3/envs/leoenv/lib/python3.10/site-packages/seaborn/categorical.py:3543: UserWarning: 41.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot: xlabel='Outcome', ylabel='Insulin'>
# /Users/tamaramelcher/opt/miniconda3/envs/leoenv/lib/python3.10/site-packages/seaborn/categorical.py:3543: UserWarning: 47.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# Keine großen Unterschiede zu sehen. Aber wieso???
# Es geht um Diabetes Mellitus Typ 2. Da Typ 1 nichts mit unseren Datensätzen zu tun hat, weil es genetisch veranlagt ist.

# %% [markdown]
# # Was hat Glucose mit Diabetes zu tun?

# %%
sns.histplot(data=diabetes_data, x='Glucose', palette=diabetes_colors, hue='Outcome', bins=10, kde='true')
# Out:
# <AxesSubplot: xlabel='Glucose', ylabel='Count'>

# %%
sns.boxplot(data=diabetes_data, x='Outcome', y='Glucose', palette=diabetes_colors, whis=[1,99])
# Out:
# <AxesSubplot: xlabel='Outcome', ylabel='Glucose'>

# %%
sns.violinplot(data=diabetes_data, x='Outcome', y='Glucose', palette=diabetes_colors, hue='Outcome')
# Out:
# <AxesSubplot: xlabel='Outcome', ylabel='Glucose'>

# %% [markdown]
# # Wie wirkt sich der BMI auf Diabetes aus?

# %%
sns.histplot(data=diabetes_data, x='BMI', palette=diabetes_colors, hue='Outcome', bins=10, kde='true')
# Out:
# <AxesSubplot: xlabel='BMI', ylabel='Count'>

# %%
sns.scatterplot(data=diabetes_data, x="Glucose", y="BloodPressure",hue='Outcome', palette=diabetes_colors)
# Out:
# <AxesSubplot: xlabel='Glucose', ylabel='BloodPressure'>

# %% [markdown]
# # Wie sehr hängt Diabetes von der Verwandschaft ab?

# %%
sns.histplot(data=diabetes_data, x='DiabetesPedigreeFunction', palette=diabetes_colors, hue='Outcome', bins=10, kde='true')
# Out:
# <AxesSubplot: xlabel='DiabetesPedigreeFunction', ylabel='Count'>

# %% [markdown]
# # Was hat das Alter für eine Auswirkung auf Diabetes?

# %%
sns.boxplot(data=diabetes_data, x='Outcome', y='Age', palette=diabetes_colors, whis=[1,99])
# Out:
# <AxesSubplot: xlabel='Outcome', ylabel='Age'>

# %% [markdown]
# # Übersicht

# %%
sns.pairplot(data=diabetes_data, hue='Outcome', palette=diabetes_colors)

# %% [markdown]
# # Korrelation

# %%
correlation = diabetes_data.corr().sort_values('Outcome', ascending=False)[['Outcome']]
sns.heatmap(correlation, annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# Die höchste Korrelation liegt bei der Glucose.
